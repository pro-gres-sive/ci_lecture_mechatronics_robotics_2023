# %%
#imports
# %matplotlib widget
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [8, 6]

import numpy as np
import pandas as pd
import tensorflow as tf

# %%
# just to make sure everyone get's the same results
random_state = 99
np.random.seed(random_state)
tf.random.set_seed(random_state)

# %%
# load training data
data = pd.read_csv('./regression_example_1.csv')

# %%
data.plot(kind='scatter', x='input', y='output', title='Training data')
# Out:
# <AxesSubplot:title={'center':'Training data'}, xlabel='input', ylabel='output'>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
training_data = data.sample(frac=0.8)
validation_data = data.drop(training_data.index)

# check len of data frames 
print(len(training_data))
print(len(validation_data))

# %%
# define model topology
inputs = tf.keras.layers.Input(shape=(1,))
x = tf.keras.layers.Dense(2, name='HiddenLayer', activation=tf.keras.activations.tanh)(inputs)
output = tf.keras.layers.Dense(1, name='OutputLayer', activation = None)(x)

# %%
# create model
model = tf.keras.Model(inputs = inputs, outputs = output, name='TF_Example')

# %%
# inspect model
model.summary()
tf.keras.utils.plot_model(model, show_shapes=True)
# Out:
# Model: "TF_Example"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 1)]               0
# _________________________________________________________________
# HiddenLayer (Dense)          (None, 2)                 4
# _________________________________________________________________
# OutputLayer (Dense)          (None, 1)                 3
# =================================================================
# Total params: 7
# Trainable params: 7
# Non-trainable params: 0
# _________________________________________________________________

# %%
learning_rate = 0.1

model.compile(loss = tf.keras.losses.MeanSquaredError(),
             optimizer = tf.keras.optimizers.Adam(learning_rate),
             metrics = [tf.keras.metrics.RootMeanSquaredError()])

# %%
history = model.fit(training_data['input'].to_numpy(), training_data['output'].to_numpy(), batch_size=5, epochs=120, validation_data=(validation_data['input'].to_numpy(), validation_data['output'].to_numpy()))
# Out:
# Epoch 1/120
# 7/7 [==============================] - 0s 13ms/step - loss: 0.2927 - root_mean_squared_error: 0.5411 - val_loss: 0.1022 - val_root_mean_squared_error: 0.3198
# Epoch 2/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0493 - root_mean_squared_error: 0.2219 - val_loss: 0.0503 - val_root_mean_squared_error: 0.2242
# Epoch 3/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0649 - root_mean_squared_error: 0.2548 - val_loss: 0.0252 - val_root_mean_squared_error: 0.1587
# Epoch 4/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0420 - root_mean_squared_error: 0.2050 - val_loss: 0.0266 - val_root_mean_squared_error: 0.1630
# Epoch 5/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0387 - root_mean_squared_error: 0.1967 - val_loss: 0.0193 - val_root_mean_squared_error: 0.1389
# Epoch 6/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0395 - root_mean_squared_error: 0.1988 - val_loss: 0.0350 - val_root_mean_squared_error: 0.1871
# Epoch 7/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0376 - root_mean_squared_error: 0.1938 - val_loss: 0.0191 - val_root_mean_squared_error: 0.1383
# Epoch 8/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0317 - root_mean_squared_error: 0.1780 - val_loss: 0.0203 - val_root_mean_squared_error: 0.1425
# Epoch 9/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0310 - root_mean_squared_error: 0.1760 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1342
# Epoch 10/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0312 - root_mean_squared_error: 0.1766 - val_loss: 0.0198 - val_root_mean_squared_error: 0.1406
# Epoch 11/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0316 - root_mean_squared_error: 0.1777 - val_loss: 0.0203 - val_root_mean_squared_error: 0.1425
# Epoch 12/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0308 - root_mean_squared_error: 0.1756 - val_loss: 0.0204 - val_root_mean_squared_error: 0.1430
# Epoch 13/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0317 - root_mean_squared_error: 0.1779 - val_loss: 0.0167 - val_root_mean_squared_error: 0.1293
# Epoch 14/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0389 - root_mean_squared_error: 0.1972 - val_loss: 0.0229 - val_root_mean_squared_error: 0.1513
# Epoch 15/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0377 - root_mean_squared_error: 0.1941 - val_loss: 0.0315 - val_root_mean_squared_error: 0.1776
# Epoch 16/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0472 - root_mean_squared_error: 0.2173 - val_loss: 0.0242 - val_root_mean_squared_error: 0.1554
# Epoch 17/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0347 - root_mean_squared_error: 0.1864 - val_loss: 0.0350 - val_root_mean_squared_error: 0.1871
# Epoch 18/120
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0316 - root_mean_squared_error: 0.1778 - val_loss: 0.0182 - val_root_mean_squared_error: 0.1348
# Epoch 19/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0313 - root_mean_squared_error: 0.1770 - val_loss: 0.0205 - val_root_mean_squared_error: 0.1433
# Epoch 20/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0263 - root_mean_squared_error: 0.1622 - val_loss: 0.0255 - val_root_mean_squared_error: 0.1596
# Epoch 21/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0294 - root_mean_squared_error: 0.1715 - val_loss: 0.0208 - val_root_mean_squared_error: 0.1442
# Epoch 22/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0254 - root_mean_squared_error: 0.1592 - val_loss: 0.0191 - val_root_mean_squared_error: 0.1383
# Epoch 23/120
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0245 - root_mean_squared_error: 0.1566 - val_loss: 0.0171 - val_root_mean_squared_error: 0.1306
# Epoch 24/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0261 - root_mean_squared_error: 0.1617 - val_loss: 0.0190 - val_root_mean_squared_error: 0.1379
# Epoch 25/120
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0438 - root_mean_squared_error: 0.2093 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1330
# Epoch 26/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0460 - root_mean_squared_error: 0.2145 - val_loss: 0.0247 - val_root_mean_squared_error: 0.1570
# Epoch 27/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0297 - root_mean_squared_error: 0.1722 - val_loss: 0.0196 - val_root_mean_squared_error: 0.1401
# Epoch 28/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0256 - root_mean_squared_error: 0.1602 - val_loss: 0.0294 - val_root_mean_squared_error: 0.1715
# Epoch 29/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0232 - root_mean_squared_error: 0.1523 - val_loss: 0.0175 - val_root_mean_squared_error: 0.1323
# Epoch 30/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0362 - root_mean_squared_error: 0.1903 - val_loss: 0.0169 - val_root_mean_squared_error: 0.1301
# Epoch 31/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0263 - root_mean_squared_error: 0.1622 - val_loss: 0.0274 - val_root_mean_squared_error: 0.1656
# Epoch 32/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0245 - root_mean_squared_error: 0.1565 - val_loss: 0.0159 - val_root_mean_squared_error: 0.1263
# Epoch 33/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0282 - root_mean_squared_error: 0.1680 - val_loss: 0.0162 - val_root_mean_squared_error: 0.1272
# Epoch 34/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0200 - root_mean_squared_error: 0.1414 - val_loss: 0.0206 - val_root_mean_squared_error: 0.1434
# Epoch 35/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0222 - root_mean_squared_error: 0.1490 - val_loss: 0.0167 - val_root_mean_squared_error: 0.1293
# Epoch 36/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0201 - root_mean_squared_error: 0.1416 - val_loss: 0.0159 - val_root_mean_squared_error: 0.1263
# Epoch 37/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0196 - root_mean_squared_error: 0.1399 - val_loss: 0.0193 - val_root_mean_squared_error: 0.1390
# Epoch 38/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0261 - root_mean_squared_error: 0.1615 - val_loss: 0.0170 - val_root_mean_squared_error: 0.1302
# Epoch 39/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0224 - root_mean_squared_error: 0.1496 - val_loss: 0.0166 - val_root_mean_squared_error: 0.1289
# Epoch 40/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0276 - root_mean_squared_error: 0.1661 - val_loss: 0.0185 - val_root_mean_squared_error: 0.1362
# Epoch 41/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0187 - root_mean_squared_error: 0.1367 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1333
# Epoch 42/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0202 - root_mean_squared_error: 0.1422 - val_loss: 0.0264 - val_root_mean_squared_error: 0.1623
# Epoch 43/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0213 - root_mean_squared_error: 0.1458 - val_loss: 0.0172 - val_root_mean_squared_error: 0.1311
# Epoch 44/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0184 - root_mean_squared_error: 0.1357 - val_loss: 0.0181 - val_root_mean_squared_error: 0.1344
# Epoch 45/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0176 - root_mean_squared_error: 0.1325 - val_loss: 0.0183 - val_root_mean_squared_error: 0.1353
# Epoch 46/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0178 - root_mean_squared_error: 0.1336 - val_loss: 0.0192 - val_root_mean_squared_error: 0.1387
# Epoch 47/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0192 - root_mean_squared_error: 0.1386 - val_loss: 0.0198 - val_root_mean_squared_error: 0.1407
# Epoch 48/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0250 - root_mean_squared_error: 0.1582 - val_loss: 0.0186 - val_root_mean_squared_error: 0.1362
# Epoch 49/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0182 - root_mean_squared_error: 0.1348 - val_loss: 0.0181 - val_root_mean_squared_error: 0.1346
# Epoch 50/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0221 - root_mean_squared_error: 0.1485 - val_loss: 0.0181 - val_root_mean_squared_error: 0.1344
# Epoch 51/120
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0283 - root_mean_squared_error: 0.1681 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1332
# Epoch 52/120
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0176 - root_mean_squared_error: 0.1325 - val_loss: 0.0192 - val_root_mean_squared_error: 0.1387
# Epoch 53/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0167 - root_mean_squared_error: 0.1291 - val_loss: 0.0222 - val_root_mean_squared_error: 0.1491
# Epoch 54/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0176 - root_mean_squared_error: 0.1327 - val_loss: 0.0199 - val_root_mean_squared_error: 0.1411
# Epoch 55/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0174 - root_mean_squared_error: 0.1318 - val_loss: 0.0182 - val_root_mean_squared_error: 0.1351
# Epoch 56/120
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0177 - root_mean_squared_error: 0.1330 - val_loss: 0.0182 - val_root_mean_squared_error: 0.1350
# Epoch 57/120
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0178 - root_mean_squared_error: 0.1335 - val_loss: 0.0186 - val_root_mean_squared_error: 0.1363
# Epoch 58/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0177 - root_mean_squared_error: 0.1332 - val_loss: 0.0203 - val_root_mean_squared_error: 0.1423
# Epoch 59/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0239 - root_mean_squared_error: 0.1544 - val_loss: 0.0219 - val_root_mean_squared_error: 0.1479
# Epoch 60/120
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0203 - root_mean_squared_error: 0.1426 - val_loss: 0.0235 - val_root_mean_squared_error: 0.1533
# Epoch 61/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0266 - root_mean_squared_error: 0.1632 - val_loss: 0.0198 - val_root_mean_squared_error: 0.1408
# Epoch 62/120
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0172 - root_mean_squared_error: 0.1312 - val_loss: 0.0193 - val_root_mean_squared_error: 0.1390
# Epoch 63/120
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0176 - root_mean_squared_error: 0.1326 - val_loss: 0.0185 - val_root_mean_squared_error: 0.1361
# Epoch 64/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0169 - root_mean_squared_error: 0.1299 - val_loss: 0.0201 - val_root_mean_squared_error: 0.1419
# Epoch 65/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0163 - root_mean_squared_error: 0.1278 - val_loss: 0.0200 - val_root_mean_squared_error: 0.1414
# Epoch 66/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0159 - root_mean_squared_error: 0.1259 - val_loss: 0.0195 - val_root_mean_squared_error: 0.1396
# Epoch 67/120
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0159 - root_mean_squared_error: 0.1262 - val_loss: 0.0204 - val_root_mean_squared_error: 0.1427
# Epoch 68/120
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0165 - root_mean_squared_error: 0.1285 - val_loss: 0.0221 - val_root_mean_squared_error: 0.1488
# Epoch 69/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0171 - root_mean_squared_error: 0.1309 - val_loss: 0.0229 - val_root_mean_squared_error: 0.1513
# Epoch 70/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0192 - root_mean_squared_error: 0.1387 - val_loss: 0.0221 - val_root_mean_squared_error: 0.1486
# Epoch 71/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0162 - root_mean_squared_error: 0.1271 - val_loss: 0.0221 - val_root_mean_squared_error: 0.1487
# Epoch 72/120
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0159 - root_mean_squared_error: 0.1263 - val_loss: 0.0224 - val_root_mean_squared_error: 0.1497
# Epoch 73/120
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0159 - root_mean_squared_error: 0.1260 - val_loss: 0.0246 - val_root_mean_squared_error: 0.1568
# Epoch 74/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0182 - root_mean_squared_error: 0.1349 - val_loss: 0.0218 - val_root_mean_squared_error: 0.1478
# Epoch 75/120
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0151 - root_mean_squared_error: 0.1230 - val_loss: 0.0269 - val_root_mean_squared_error: 0.1640
# Epoch 76/120
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0157 - root_mean_squared_error: 0.1251 - val_loss: 0.0229 - val_root_mean_squared_error: 0.1514
# Epoch 77/120
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0170 - root_mean_squared_error: 0.1303 - val_loss: 0.0226 - val_root_mean_squared_error: 0.1504
# Epoch 78/120
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0155 - root_mean_squared_error: 0.1246 - val_loss: 0.0234 - val_root_mean_squared_error: 0.1529
# Epoch 79/120
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0161 - root_mean_squared_error: 0.1269 - val_loss: 0.0230 - val_root_mean_squared_error: 0.1516
# Epoch 80/120
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0191 - root_mean_squared_error: 0.1382 - val_loss: 0.0290 - val_root_mean_squared_error: 0.1703
# Epoch 81/120
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0222 - root_mean_squared_error: 0.1490 - val_loss: 0.0260 - val_root_mean_squared_error: 0.1612
# Epoch 82/120
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0177 - root_mean_squared_error: 0.1332 - val_loss: 0.0312 - val_root_mean_squared_error: 0.1765
# Epoch 83/120
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0223 - root_mean_squared_error: 0.1493 - val_loss: 0.0245 - val_root_mean_squared_error: 0.1567
# Epoch 84/120
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0202 - root_mean_squared_error: 0.1421 - val_loss: 0.0212 - val_root_mean_squared_error: 0.1457
# Epoch 85/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0201 - root_mean_squared_error: 0.1417 - val_loss: 0.0211 - val_root_mean_squared_error: 0.1453
# Epoch 86/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0256 - root_mean_squared_error: 0.1599 - val_loss: 0.0190 - val_root_mean_squared_error: 0.1378
# Epoch 87/120
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0226 - root_mean_squared_error: 0.1503 - val_loss: 0.0246 - val_root_mean_squared_error: 0.1570
# Epoch 88/120
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0187 - root_mean_squared_error: 0.1367 - val_loss: 0.0198 - val_root_mean_squared_error: 0.1406
# Epoch 89/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0158 - root_mean_squared_error: 0.1255 - val_loss: 0.0197 - val_root_mean_squared_error: 0.1403
# Epoch 90/120
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0164 - root_mean_squared_error: 0.1279 - val_loss: 0.0186 - val_root_mean_squared_error: 0.1365
# Epoch 91/120
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0158 - root_mean_squared_error: 0.1258 - val_loss: 0.0199 - val_root_mean_squared_error: 0.1412
# Epoch 92/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0149 - root_mean_squared_error: 0.1221 - val_loss: 0.0212 - val_root_mean_squared_error: 0.1456
# Epoch 93/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0165 - root_mean_squared_error: 0.1285 - val_loss: 0.0226 - val_root_mean_squared_error: 0.1505
# Epoch 94/120
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0205 - root_mean_squared_error: 0.1432 - val_loss: 0.0253 - val_root_mean_squared_error: 0.1592
# Epoch 95/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0347 - root_mean_squared_error: 0.1861 - val_loss: 0.0337 - val_root_mean_squared_error: 0.1836
# Epoch 96/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0155 - root_mean_squared_error: 0.1247 - val_loss: 0.0215 - val_root_mean_squared_error: 0.1466
# Epoch 97/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0266 - root_mean_squared_error: 0.1631 - val_loss: 0.0197 - val_root_mean_squared_error: 0.1404
# Epoch 98/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0222 - root_mean_squared_error: 0.1490 - val_loss: 0.0212 - val_root_mean_squared_error: 0.1455
# Epoch 99/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0198 - root_mean_squared_error: 0.1407 - val_loss: 0.0189 - val_root_mean_squared_error: 0.1373
# Epoch 100/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0245 - root_mean_squared_error: 0.1565 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1340
# Epoch 101/120
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0182 - root_mean_squared_error: 0.1347 - val_loss: 0.0194 - val_root_mean_squared_error: 0.1393
# Epoch 102/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0182 - root_mean_squared_error: 0.1348 - val_loss: 0.0236 - val_root_mean_squared_error: 0.1537
# Epoch 103/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0190 - root_mean_squared_error: 0.1379 - val_loss: 0.0183 - val_root_mean_squared_error: 0.1351
# Epoch 104/120
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0181 - root_mean_squared_error: 0.1344 - val_loss: 0.0201 - val_root_mean_squared_error: 0.1416
# Epoch 105/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0166 - root_mean_squared_error: 0.1287 - val_loss: 0.0227 - val_root_mean_squared_error: 0.1506
# Epoch 106/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0188 - root_mean_squared_error: 0.1371 - val_loss: 0.0190 - val_root_mean_squared_error: 0.1378
# Epoch 107/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0165 - root_mean_squared_error: 0.1285 - val_loss: 0.0188 - val_root_mean_squared_error: 0.1370
# Epoch 108/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0173 - root_mean_squared_error: 0.1315 - val_loss: 0.0198 - val_root_mean_squared_error: 0.1405
# Epoch 109/120
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0203 - root_mean_squared_error: 0.1426 - val_loss: 0.0230 - val_root_mean_squared_error: 0.1517
# Epoch 110/120
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0337 - root_mean_squared_error: 0.1835 - val_loss: 0.0215 - val_root_mean_squared_error: 0.1466
# Epoch 111/120
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0240 - root_mean_squared_error: 0.1549 - val_loss: 0.0211 - val_root_mean_squared_error: 0.1453
# Epoch 112/120
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0271 - root_mean_squared_error: 0.1646 - val_loss: 0.0194 - val_root_mean_squared_error: 0.1394
# Epoch 113/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0222 - root_mean_squared_error: 0.1491 - val_loss: 0.0189 - val_root_mean_squared_error: 0.1375
# Epoch 114/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0174 - root_mean_squared_error: 0.1319 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1341
# Epoch 115/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0165 - root_mean_squared_error: 0.1283 - val_loss: 0.0213 - val_root_mean_squared_error: 0.1458
# Epoch 116/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0208 - root_mean_squared_error: 0.1442 - val_loss: 0.0207 - val_root_mean_squared_error: 0.1437
# Epoch 117/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0212 - root_mean_squared_error: 0.1455 - val_loss: 0.0207 - val_root_mean_squared_error: 0.1440
# Epoch 118/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0199 - root_mean_squared_error: 0.1411 - val_loss: 0.0222 - val_root_mean_squared_error: 0.1491
# Epoch 119/120
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0165 - root_mean_squared_error: 0.1283 - val_loss: 0.0212 - val_root_mean_squared_error: 0.1456
# Epoch 120/120
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0147 - root_mean_squared_error: 0.1210 - val_loss: 0.0245 - val_root_mean_squared_error: 0.1565

# %%
pd.DataFrame(history.history).plot()
# Out:
# <AxesSubplot:>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
dummy_input_data = np.linspace(0, 1, 101)
y_pred = model.predict(dummy_input_data)

# %%
plt.close('all')
plt.scatter(data['input'], data['output'], label='training data')
plt.plot(dummy_input_data, y_pred, color='red', linewidth=3, label='prediction')
plt.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
layers = model.layers


for layer in layers:
    weights =layer.get_weights()
    
    if len(weights) == 0:
        continue

    weights_w = weights[0]
    weights_b = weights[1]
    
    print(f'Weights of {layer.name}: ')
    print(weights_w)
    print(f'Bias of {layer.name}: ')
    print(weights_b)
    print('')
# Out:
# Weights of HiddenLayer:
# [[5.5616283 3.0973763]]
# Bias of HiddenLayer:
# [-2.0877903 -2.0403411]
#
# Weights of OutputLayer:
# [[ 0.90335584]
#  [-1.0517476 ]]
# Bias of OutputLayer:
# [-0.1337787]
